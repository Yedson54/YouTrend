# %%
import requests
import time
import numpy as np
import pandas as pd
import copy

# %%
def post_request_ytb(country_code_list, trending_type_dict):
    responses_dict = {}
    for country_code in country_code_list:
        responses_dict[country_code] = {}
        for trending_type, trending_type_url in trending_type_dict.items():
            json_data = {
                'context': {
                    'client': {
                        'gl': country_code,
                        'clientName': 'WEB',
                        'clientVersion': '2.20231115.01.01',
                        'originalUrl': 'https://www.youtube.com/feed/trending',
                    },
                },
                'browseId': 'FEtrending',
                'params': trending_type_url,
            }

            response = requests.post(
                'https://www.youtube.com/youtubei/v1/browse',
                json=json_data,
            )
            responses_dict[country_code][trending_type] = response.json()
    return responses_dict

# %%
def post_request_ytb(country_code_list, trending_type_dict):
    responses_dict = {}
    for country_code in country_code_list:
        responses_dict[country_code] = {}
        for trending_type, trending_type_url in trending_type_dict.items():
            json_data = {
                'context': {
                    'client': {
                        'gl': country_code,
                        'clientName': 'WEB',
                        'clientVersion': '2.20231115.01.01',
                        'originalUrl': 'https://www.youtube.com/feed/trending',
                    },
                },
                'browseId': 'FEtrending',
                'params': trending_type_url,
            }

            response = requests.post(
                'https://www.youtube.com/youtubei/v1/browse',
                json=json_data,
            )
            responses_dict[country_code][trending_type] = response.json()
    return responses_dict

# %%
def post_request_ytb(country_code_list, trending_type_dict):
    responses_dict = {}
    for country_code in country_code_list:
        responses_dict[country_code] = {}
        for trending_type, trending_type_url in trending_type_dict.items():
            json_data = {
                'context': {
                    'client': {
                        'gl': country_code,
                        'clientName': 'WEB',
                        'clientVersion': '2.20231115.01.01',
                        'originalUrl': 'https://www.youtube.com/feed/trending',
                    },
                },
                'browseId': 'FEtrending',
                'params': trending_type_url,
            }

            response = requests.post(
                'https://www.youtube.com/youtubei/v1/browse',
                json=json_data,
            )
            responses_dict[country_code][trending_type] = response.json()
    return responses_dict

# %%
def post_request_ytb(country_code_list, trending_type_dict):
    responses_dict = {}
    for country_code in country_code_list:
        responses_dict[country_code] = {}
        for trending_type, trending_type_url in trending_type_dict.items():
            json_data = {
                'context': {
                    'client': {
                        'gl': country_code,
                        'clientName': 'WEB',
                        'clientVersion': '2.20231115.01.01',
                        'originalUrl': 'https://www.youtube.com/feed/trending',
                    },
                },
                'browseId': 'FEtrending',
                'params': trending_type_url,
            }

            response = requests.post(
                'https://www.youtube.com/youtubei/v1/browse',
                json=json_data,
            )
            responses_dict[country_code][trending_type] = response.json()
    return responses_dict

# %%
def collect_video_data(video_list, data_dictionary, trending_type, country_code, current_timestamp):
    # Collect data (generic videos) INPLACE
    nb_items = len(video_list)
    data_dictionary["videoId"] += [video_list[k]["videoRenderer"]["videoId"] for k in range(nb_items)]
    data_dictionary["videoType"] += [trending_type for k in range(nb_items)]
    data_dictionary["trendingCountry"] += [country_code for k in range(nb_items)]
    data_dictionary["videoTrendsRanking"] += [k for k in range(nb_items)]
    data_dictionary["scanTimestamp"] += [current_timestamp for k in range(nb_items)]
    return None

# %%
def collect_short_data(shorts_list, data_dictionary, country_code, current_timestamp):
    # Collect data (generic videos) INPLACE
    nb_items = len(shorts_list)
    data_dictionary["videoId"] += [shorts_list[k]["reelItemRenderer"]["videoId"] for k in range(nb_items)]
    data_dictionary["videoType"] += ['Short' for k in range(nb_items)]
    data_dictionary["trendingCountry"] += [country_code for k in range(nb_items)]
    data_dictionary["videoTrendsRanking"] += [k for k in range(nb_items)]
    data_dictionary["scanTimestamp"] += [current_timestamp for k in range(nb_items)]
    return None

# %%
def add_now_videos_shorts(response_dict, data_dictionary, current_timestamp):
    # Update data_dictionary with "Now", "Recently Trending" and "Shorts" videos data INPLACE
    for country_code in response_dict.keys():
        print("Current country : ", country_code)
        section_now = response_dict[country_code]['Now']["contents"]["twoColumnBrowseResultsRenderer"]["tabs"][0]["tabRenderer"]["content"]["sectionListRenderer"]["contents"]
        try:
            list_videos_before = section_now[0]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
            shorts_list = section_now[1]["itemSectionRenderer"]["contents"][0]["reelShelfRenderer"]["items"]
            list_videos_after = section_now[2]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
            list_videos_recently = section_now[3]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
        except KeyError:
            list_videos_before = section_now[1]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
            shorts_list = section_now[2]["itemSectionRenderer"]["contents"][0]["reelShelfRenderer"]["items"]
            list_videos_after = section_now[3]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
            list_videos_recently = section_now[4]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
        collect_video_data(list_videos_before, data_dictionary, 'Now', country_code, current_timestamp)
        collect_video_data(list_videos_after, data_dictionary, 'Now', country_code, current_timestamp)
        collect_video_data(list_videos_recently, data_dictionary, 'Recently Trending', country_code, current_timestamp)
        collect_short_data(shorts_list, data_dictionary, country_code, current_timestamp)
    return None

# %%
def add_other_sections(response_dict, data_dictionary, current_timestamp):
    # Update data_dictionary with "Music", "Gaming", "Movies" videos data INPLACE
    for country_code in response_dict.keys():
        for idx, key in enumerate(response_dict[country_code].keys()): # in recent Python versions, dictionary are ordered
            if idx != 0:
                sections = response_dict[country_code][key]["contents"]["twoColumnBrowseResultsRenderer"]["tabs"][idx]["tabRenderer"]["content"]["sectionListRenderer"]["contents"]
                video_list = sections[0]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
                collect_video_data(video_list, data_dictionary, key, country_code, current_timestamp)
    return None

# %%
def update_video_data(data_dictionary):
    # Update data for individual videos in data_dictionary INPLACE
    for video_id in data_dictionary["videoId"]:
        print("Currently processing video_id:", video_id)
        json_data = {
            'context': {
                'client': {
                    'clientName': 'WEB',
                    'clientVersion': '2.20231208.01.00',            
                    }
            },
            'videoId': video_id,
        }
        
        response = requests.post('https://www.youtube.com/youtubei/v1/next', json=json_data)
        video_response = response.json()
        individual_video_data = video_response["contents"]["twoColumnWatchNextResults"]["results"]["results"]["contents"]
        data_dictionary["exactViewNumber"].append(individual_video_data[0]["videoPrimaryInfoRenderer"]["viewCount"]["videoViewCountRenderer"]["viewCount"]["simpleText"])
        data_dictionary["numberLikes"].append(individual_video_data[0]["videoPrimaryInfoRenderer"]["videoActions"]["menuRenderer"]["topLevelButtons"][0]["segmentedLikeDislikeButtonViewModel"]["likeButtonViewModel"]["likeButtonViewModel"]["toggleButtonViewModel"]["toggleButtonViewModel"]["defaultButtonViewModel"]["buttonViewModel"]["title"])
        data_dictionary["creatorSubscriberNumber"].append(individual_video_data[1]["videoSecondaryInfoRenderer"]["owner"]["videoOwnerRenderer"]["subscriberCountText"]["simpleText"])     
        try:    
            data_dictionary["numberOfComments"].append(individual_video_data[2]["itemSectionRenderer"]["contents"][0]["commentsEntryPointHeaderRenderer"]["commentCount"]["simpleText"])
        except KeyError: # correct for additional "merchandise" section
            try:
                data_dictionary["numberOfComments"].append(individual_video_data[3]["itemSectionRenderer"]["contents"][0]["commentsEntryPointHeaderRenderer"]["commentCount"]["simpleText"])
            except IndexError: # comments are turned off
                data_dictionary["numberOfComments"].append(np.nan)
        try:
            data_dictionary["isCreatorVerified"].append(individual_video_data[1]["videoSecondaryInfoRenderer"]["owner"]["videoOwnerRenderer"]["badges"][0]["metadataBadgeRenderer"]["tooltip"] == "Verified")
        except KeyError:
            data_dictionary["isCreatorVerified"].append(False)    
        time.sleep(1)
    return None

# %%
def update_meta_data(data_dictionary):
    # Update metadata for individual videos in data_dictionary INPLACE
    for video_id in data_dictionary["videoId"]:
        print("Currently processing video_id:", video_id)
        json_data = {
        'context': {
            'client': {
                'clientName': 'WEB',
                'clientVersion': '2.20231208.01.00',
            },
        },
        'videoId': video_id,
        }
        
        response = requests.post('https://www.youtube.com/youtubei/v1/player', json=json_data)
        
        meta_response = response.json()
        try:
            data_dictionary["videoKeywords"].append(meta_response["videoDetails"]["keywords"])
        except KeyError: # no keywords
            data_dictionary["videoKeywords"].append(np.nan)
        data_dictionary["videoLengthSeconds"].append(meta_response["videoDetails"]["lengthSeconds"])
        data_dictionary["videoCategory"].append(meta_response["microformat"]["playerMicroformatRenderer"]["category"])
        data_dictionary["videoExactPublishDate"].append(meta_response["microformat"]["playerMicroformatRenderer"]["uploadDate"])
        time.sleep(1)
    return None

# %%
TRENDING_TYPE_DICT = {
    'Now': None,
    # 'Music': '4gINGgt5dG1hX2NoYXJ0cw%3D%3D',
    # 'Gaming': '4gIcGhpnYW1pbmdfY29ycHVzX21vc3RfcG9wdWxhcg%3D%3D',
    # 'Movie': '4gIKGgh0cmFpbGVycw%3D%3D',
}

FRENCH_COUNTRY_DICT = ['FR']

# %%
def scan_trending_ytb(n_scans=5, delta_scans=1800):
    """

    Args:
        n_scans (_type_): nombre de fois ou les tendances sont scannees
        delta_scans (_type_): delai entre deux scans des tendances (en secondes)
        
    """
    data_dictionary = {
    'videoId': [],
    'scanTimestamp': [],
    'videoExactPublishDate': [],
    'creatorSubscriberNumber': [],
    'videoTrendsRanking': [],
    'videoLengthSeconds': [],
    'videoType': [],
    'videoCategory': [],
    'trendingCountry': [],
    'exactViewNumber': [],
    'numberLikes': [],
    'numberOfComments': [],
    'isCreatorVerified': [],
    'videoKeywords': []
}
    data_dictionary_panel = [copy.deepcopy(data_dictionary) for k in range(n_scans)]
    Epoches=["Epoch" for k in range(n_scans)] #cette colonne supplémentaire définit pour chaque ligne, l'époque-un entier- à laquelle elle a été scappé
    les_tailles=np.zeros(n_scans,dtype=int) #ce tableau 1D  contient pour chaque Dataframe scappé, le nombre de ligne du Dataframe
    for scan in range(n_scans):
        current_timestamp = time.time()
        response_dict = post_request_ytb(FRENCH_COUNTRY_DICT, TRENDING_TYPE_DICT)
        add_now_videos_shorts(response_dict, data_dictionary_panel[scan], current_timestamp)
        add_other_sections(response_dict, data_dictionary_panel[scan], current_timestamp)
        update_video_data(data_dictionary_panel[scan])
        update_meta_data(data_dictionary_panel[scan])
        for k in data_dictionary_panel[scan].keys():
            print(len(data_dictionary_panel[scan][k]))
            les_tailles[scan]=int(len(data_dictionary_panel[scan][k]))
        time.sleep(delta_scans)
        #cles_zero=cles[0]
        #n=data_dictionary_panel[scan][cles_zero].shape[0]
        n=les_tailles[scan]
        data_dictionary_panel[scan][Epoches[scan]]=np.full(n,scan+1)
        # aprés chaque collecte, on met le résultats dans un datframe 
        pd.DataFrame(data_dictionary_panel[scan]).to_csv('Dataset_{}.csv'.format(scan))

    return pd.concat([pd.DataFrame(lst) for lst in data_dictionary_panel])

# %%
#le code ci dessous, nous a permis de collecter 7 fois les vidéos en tendances pour des intervalles de temps de collecte d'1h= 60*60=3600 seconde

# %%
scan_trending_ytb(7,3600)
# Out:
# Current country :  FR
# Currently processing video_id: bfmUsDJjBkU
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: tfht2Piljo8
# Currently processing video_id: ziq9BzdRvwY
# Currently processing video_id: pIqARNahjJw
# Currently processing video_id: usTqmg0xNZY
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: SwlRSu0jjyU
# Currently processing video_id: FrTfxDY2eyI
# Currently processing video_id: W_l0npDNILY
# Currently processing video_id: NGfpot1_2Is
# Currently processing video_id: igsQae0v0HQ
# Currently processing video_id: TOIAdoDwYYs
# Currently processing video_id: uKpgHMkjF_8
# Currently processing video_id: LY0Ll7LRYDI
# Currently processing video_id: lTmJJ3AGizk
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: WG4FIkH6HU8
# Currently processing video_id: DmdcktG7vXM
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: gRb87CBRZ2o
# Currently processing video_id: spmAWUn0k40
# Currently processing video_id: P0rMYaKFO7k
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: jply2m0IoYs
# Currently processing video_id: -3Xvyo_-Pyg
# Currently processing video_id: icGwtYWesWw
# Currently processing video_id: k51hM1cEgcs
# Currently processing video_id: Mz-J5JPxxBI
# Currently processing video_id: JGP98IDCrTc
# Currently processing video_id: RrasC4E_1R8
# Currently processing video_id: bOppj5rT2xA
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: BYKz4ksSFFc
# Currently processing video_id: mWacdcatC9o
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: sRtFQf5wQ-U
# Currently processing video_id: 5VojZY6p798
# Currently processing video_id: qj9REJK5K3w
# Currently processing video_id: 5jrMwhmYW1A
# Currently processing video_id: QdBZY2fkU-0
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: HRfFR2z35hk
# Currently processing video_id: 6MXIRMi1tS8
# Currently processing video_id: ZjrQ11eSsJY
# Currently processing video_id: 9P6xy-AC9Is
# Currently processing video_id: r1R7JgStaBw
# Currently processing video_id: DO3dTP9h6ho
# Currently processing video_id: koGrjBe5kFE
# Currently processing video_id: 3mHwQzN2Po4
# Currently processing video_id: l-ERLYPYFcc
# Currently processing video_id: 67rSnZKLef0
# Currently processing video_id: _Q4pcR5H2OE
# Currently processing video_id: BSop5zkR7KY
# Currently processing video_id: iFDN9N-GIrw
# Currently processing video_id: 9AYGP5imeWk
# Currently processing video_id: IMsEt4YBF3Q
# Currently processing video_id: bfmUsDJjBkU
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: tfht2Piljo8
# Currently processing video_id: ziq9BzdRvwY
# Currently processing video_id: pIqARNahjJw
# Currently processing video_id: usTqmg0xNZY
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: SwlRSu0jjyU
# Currently processing video_id: FrTfxDY2eyI
# Currently processing video_id: W_l0npDNILY
# Currently processing video_id: NGfpot1_2Is
# Currently processing video_id: igsQae0v0HQ
# Currently processing video_id: TOIAdoDwYYs
# Currently processing video_id: uKpgHMkjF_8
# Currently processing video_id: LY0Ll7LRYDI
# Currently processing video_id: lTmJJ3AGizk
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: WG4FIkH6HU8
# Currently processing video_id: DmdcktG7vXM
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: gRb87CBRZ2o
# Currently processing video_id: spmAWUn0k40
# Currently processing video_id: P0rMYaKFO7k
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: jply2m0IoYs
# Currently processing video_id: -3Xvyo_-Pyg
# Currently processing video_id: icGwtYWesWw
# Currently processing video_id: k51hM1cEgcs
# Currently processing video_id: Mz-J5JPxxBI
# Currently processing video_id: JGP98IDCrTc
# Currently processing video_id: RrasC4E_1R8
# Currently processing video_id: bOppj5rT2xA
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: BYKz4ksSFFc
# Currently processing video_id: mWacdcatC9o
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: sRtFQf5wQ-U
# Currently processing video_id: 5VojZY6p798
# Currently processing video_id: qj9REJK5K3w
# Currently processing video_id: 5jrMwhmYW1A
# Currently processing video_id: QdBZY2fkU-0
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: HRfFR2z35hk
# Currently processing video_id: 6MXIRMi1tS8
# Currently processing video_id: ZjrQ11eSsJY
# Currently processing video_id: 9P6xy-AC9Is
# Currently processing video_id: r1R7JgStaBw
# Currently processing video_id: DO3dTP9h6ho
# Currently processing video_id: koGrjBe5kFE
# Currently processing video_id: 3mHwQzN2Po4
# Currently processing video_id: l-ERLYPYFcc
# Currently processing video_id: 67rSnZKLef0
# Currently processing video_id: _Q4pcR5H2OE
# Currently processing video_id: BSop5zkR7KY
# Currently processing video_id: iFDN9N-GIrw
# Currently processing video_id: 9AYGP5imeWk
# Currently processing video_id: IMsEt4YBF3Q
# 113
# 113
# 113
# 113
# 113
# 113
# 113
# 113
# 113
# 113
# 113
# 113
# 113
# 113
# Current country :  FR
# Currently processing video_id: bfmUsDJjBkU
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: tfht2Piljo8
# Currently processing video_id: pIqARNahjJw
# Currently processing video_id: usTqmg0xNZY
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: ziq9BzdRvwY
# Currently processing video_id: SwlRSu0jjyU
# Currently processing video_id: FrTfxDY2eyI
# Currently processing video_id: W_l0npDNILY
# Currently processing video_id: NGfpot1_2Is
# Currently processing video_id: TOIAdoDwYYs
# Currently processing video_id: uKpgHMkjF_8
# Currently processing video_id: LY0Ll7LRYDI
# Currently processing video_id: lTmJJ3AGizk
# Currently processing video_id: igsQae0v0HQ
# Currently processing video_id: WG4FIkH6HU8
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: DmdcktG7vXM
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: gRb87CBRZ2o
# Currently processing video_id: P0rMYaKFO7k
# Currently processing video_id: spmAWUn0k40
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: jply2m0IoYs
# Currently processing video_id: icGwtYWesWw
# Currently processing video_id: k51hM1cEgcs
# Currently processing video_id: -3Xvyo_-Pyg
# Currently processing video_id: JGP98IDCrTc
# Currently processing video_id: Mz-J5JPxxBI
# Currently processing video_id: RrasC4E_1R8
# Currently processing video_id: bOppj5rT2xA
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: mWacdcatC9o
# Currently processing video_id: BYKz4ksSFFc
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: sRtFQf5wQ-U
# Currently processing video_id: 5VojZY6p798
# Currently processing video_id: qj9REJK5K3w
# Currently processing video_id: 5jrMwhmYW1A
# Currently processing video_id: QdBZY2fkU-0
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: HRfFR2z35hk
# Currently processing video_id: 6MXIRMi1tS8
# Currently processing video_id: ZjrQ11eSsJY
# Currently processing video_id: 9P6xy-AC9Is
# Currently processing video_id: r1R7JgStaBw
# Currently processing video_id: DO3dTP9h6ho
# Currently processing video_id: koGrjBe5kFE
# Currently processing video_id: 3mHwQzN2Po4
# Currently processing video_id: 67rSnZKLef0
# Currently processing video_id: BSop5zkR7KY
# Currently processing video_id: _Q4pcR5H2OE
# Currently processing video_id: iFDN9N-GIrw
# Currently processing video_id: 9AYGP5imeWk
# Currently processing video_id: l-ERLYPYFcc
# Currently processing video_id: IMsEt4YBF3Q
# Currently processing video_id: bfmUsDJjBkU
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: tfht2Piljo8
# Currently processing video_id: pIqARNahjJw
# Currently processing video_id: usTqmg0xNZY
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: ziq9BzdRvwY
# Currently processing video_id: SwlRSu0jjyU
# Currently processing video_id: FrTfxDY2eyI
# Currently processing video_id: W_l0npDNILY
# Currently processing video_id: NGfpot1_2Is
# Currently processing video_id: TOIAdoDwYYs
# Currently processing video_id: uKpgHMkjF_8
# Currently processing video_id: LY0Ll7LRYDI
# Currently processing video_id: lTmJJ3AGizk
# Currently processing video_id: igsQae0v0HQ
# Currently processing video_id: WG4FIkH6HU8
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: DmdcktG7vXM
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: gRb87CBRZ2o
# Currently processing video_id: P0rMYaKFO7k
# Currently processing video_id: spmAWUn0k40
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: jply2m0IoYs
# Currently processing video_id: icGwtYWesWw
# Currently processing video_id: k51hM1cEgcs
# Currently processing video_id: -3Xvyo_-Pyg
# Currently processing video_id: JGP98IDCrTc
# Currently processing video_id: Mz-J5JPxxBI
# Currently processing video_id: RrasC4E_1R8
# Currently processing video_id: bOppj5rT2xA
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: mWacdcatC9o
# Currently processing video_id: BYKz4ksSFFc
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: sRtFQf5wQ-U
# Currently processing video_id: 5VojZY6p798
# Currently processing video_id: qj9REJK5K3w
# Currently processing video_id: 5jrMwhmYW1A
# Currently processing video_id: QdBZY2fkU-0
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: HRfFR2z35hk
# Currently processing video_id: 6MXIRMi1tS8
# Currently processing video_id: ZjrQ11eSsJY
# Currently processing video_id: 9P6xy-AC9Is
# Currently processing video_id: r1R7JgStaBw
# Currently processing video_id: DO3dTP9h6ho
# Currently processing video_id: koGrjBe5kFE
# Currently processing video_id: 3mHwQzN2Po4
# Currently processing video_id: 67rSnZKLef0
# Currently processing video_id: BSop5zkR7KY
# Currently processing video_id: _Q4pcR5H2OE
# Currently processing video_id: iFDN9N-GIrw
# Currently processing video_id: 9AYGP5imeWk
# Currently processing video_id: l-ERLYPYFcc
# Currently processing video_id: IMsEt4YBF3Q
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# Current country :  FR
# Currently processing video_id: bfmUsDJjBkU
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: tfht2Piljo8
# Currently processing video_id: pIqARNahjJw
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: usTqmg0xNZY
# Currently processing video_id: SwlRSu0jjyU
# Currently processing video_id: FrTfxDY2eyI
# Currently processing video_id: ziq9BzdRvwY
# Currently processing video_id: W_l0npDNILY
# Currently processing video_id: NGfpot1_2Is
# Currently processing video_id: TOIAdoDwYYs
# Currently processing video_id: uKpgHMkjF_8
# Currently processing video_id: LY0Ll7LRYDI
# Currently processing video_id: lTmJJ3AGizk
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: WG4FIkH6HU8
# Currently processing video_id: igsQae0v0HQ
# Currently processing video_id: DmdcktG7vXM
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: gRb87CBRZ2o
# Currently processing video_id: P0rMYaKFO7k
# Currently processing video_id: spmAWUn0k40
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: jply2m0IoYs
# Currently processing video_id: icGwtYWesWw
# Currently processing video_id: k51hM1cEgcs
# Currently processing video_id: -3Xvyo_-Pyg
# Currently processing video_id: JGP98IDCrTc
# Currently processing video_id: Mz-J5JPxxBI
# Currently processing video_id: bOppj5rT2xA
# Currently processing video_id: RrasC4E_1R8
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: mWacdcatC9o
# Currently processing video_id: BYKz4ksSFFc
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: sRtFQf5wQ-U
# Currently processing video_id: 5VojZY6p798
# Currently processing video_id: qj9REJK5K3w
# Currently processing video_id: 5jrMwhmYW1A
# Currently processing video_id: QdBZY2fkU-0
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: HRfFR2z35hk
# Currently processing video_id: 6MXIRMi1tS8
# Currently processing video_id: ZjrQ11eSsJY
# Currently processing video_id: 9P6xy-AC9Is
# Currently processing video_id: r1R7JgStaBw
# Currently processing video_id: DO3dTP9h6ho
# Currently processing video_id: koGrjBe5kFE
# Currently processing video_id: 3mHwQzN2Po4
# Currently processing video_id: 67rSnZKLef0
# Currently processing video_id: BSop5zkR7KY
# Currently processing video_id: _Q4pcR5H2OE
# Currently processing video_id: iFDN9N-GIrw
# Currently processing video_id: 9AYGP5imeWk
# Currently processing video_id: IMsEt4YBF3Q
# Currently processing video_id: 13DDTAbaL-A
# Currently processing video_id: bfmUsDJjBkU
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: tfht2Piljo8
# Currently processing video_id: pIqARNahjJw
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: usTqmg0xNZY
# Currently processing video_id: SwlRSu0jjyU
# Currently processing video_id: FrTfxDY2eyI
# Currently processing video_id: ziq9BzdRvwY
# Currently processing video_id: W_l0npDNILY
# Currently processing video_id: NGfpot1_2Is
# Currently processing video_id: TOIAdoDwYYs
# Currently processing video_id: uKpgHMkjF_8
# Currently processing video_id: LY0Ll7LRYDI
# Currently processing video_id: lTmJJ3AGizk
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: WG4FIkH6HU8
# Currently processing video_id: igsQae0v0HQ
# Currently processing video_id: DmdcktG7vXM
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: gRb87CBRZ2o
# Currently processing video_id: P0rMYaKFO7k
# Currently processing video_id: spmAWUn0k40
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: jply2m0IoYs
# Currently processing video_id: icGwtYWesWw
# Currently processing video_id: k51hM1cEgcs
# Currently processing video_id: -3Xvyo_-Pyg
# Currently processing video_id: JGP98IDCrTc
# Currently processing video_id: Mz-J5JPxxBI
# Currently processing video_id: bOppj5rT2xA
# Currently processing video_id: RrasC4E_1R8
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: mWacdcatC9o
# Currently processing video_id: BYKz4ksSFFc
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: sRtFQf5wQ-U
# Currently processing video_id: 5VojZY6p798
# Currently processing video_id: qj9REJK5K3w
# Currently processing video_id: 5jrMwhmYW1A
# Currently processing video_id: QdBZY2fkU-0
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: HRfFR2z35hk
# Currently processing video_id: 6MXIRMi1tS8
# Currently processing video_id: ZjrQ11eSsJY
# Currently processing video_id: 9P6xy-AC9Is
# Currently processing video_id: r1R7JgStaBw
# Currently processing video_id: DO3dTP9h6ho
# Currently processing video_id: koGrjBe5kFE
# Currently processing video_id: 3mHwQzN2Po4
# Currently processing video_id: 67rSnZKLef0
# Currently processing video_id: BSop5zkR7KY
# Currently processing video_id: _Q4pcR5H2OE
# Currently processing video_id: iFDN9N-GIrw
# Currently processing video_id: 9AYGP5imeWk
# Currently processing video_id: IMsEt4YBF3Q
# Currently processing video_id: 13DDTAbaL-A
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# Current country :  FR
# Currently processing video_id: bfmUsDJjBkU
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: pIqARNahjJw
# Currently processing video_id: tfht2Piljo8
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: usTqmg0xNZY
# Currently processing video_id: SwlRSu0jjyU
# Currently processing video_id: FrTfxDY2eyI
# Currently processing video_id: NGfpot1_2Is
# Currently processing video_id: W_l0npDNILY
# Currently processing video_id: ziq9BzdRvwY
# Currently processing video_id: TOIAdoDwYYs
# Currently processing video_id: uKpgHMkjF_8
# Currently processing video_id: LY0Ll7LRYDI
# Currently processing video_id: lTmJJ3AGizk
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: WG4FIkH6HU8
# Currently processing video_id: DmdcktG7vXM
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: gRb87CBRZ2o
# Currently processing video_id: P0rMYaKFO7k
# Currently processing video_id: igsQae0v0HQ
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: spmAWUn0k40
# Currently processing video_id: jply2m0IoYs
# Currently processing video_id: icGwtYWesWw
# Currently processing video_id: k51hM1cEgcs
# Currently processing video_id: -3Xvyo_-Pyg
# Currently processing video_id: JGP98IDCrTc
# Currently processing video_id: bOppj5rT2xA
# Currently processing video_id: Mz-J5JPxxBI
# Currently processing video_id: RrasC4E_1R8
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: mWacdcatC9o
# Currently processing video_id: BYKz4ksSFFc
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: sRtFQf5wQ-U
# Currently processing video_id: 5VojZY6p798
# Currently processing video_id: qj9REJK5K3w
# Currently processing video_id: 5jrMwhmYW1A
# Currently processing video_id: QdBZY2fkU-0
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: HRfFR2z35hk
# Currently processing video_id: 6MXIRMi1tS8
# Currently processing video_id: ZjrQ11eSsJY
# Currently processing video_id: 9P6xy-AC9Is
# Currently processing video_id: r1R7JgStaBw
# Currently processing video_id: DO3dTP9h6ho
# Currently processing video_id: koGrjBe5kFE
# Currently processing video_id: 3mHwQzN2Po4
# Currently processing video_id: 67rSnZKLef0
# Currently processing video_id: BSop5zkR7KY
# Currently processing video_id: _Q4pcR5H2OE
# Currently processing video_id: iFDN9N-GIrw
# Currently processing video_id: 9AYGP5imeWk
# Currently processing video_id: IMsEt4YBF3Q
# Currently processing video_id: 13DDTAbaL-A
# Currently processing video_id: bfmUsDJjBkU
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: pIqARNahjJw
# Currently processing video_id: tfht2Piljo8
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: usTqmg0xNZY
# Currently processing video_id: SwlRSu0jjyU
# Currently processing video_id: FrTfxDY2eyI
# Currently processing video_id: NGfpot1_2Is
# Currently processing video_id: W_l0npDNILY
# Currently processing video_id: ziq9BzdRvwY
# Currently processing video_id: TOIAdoDwYYs
# Currently processing video_id: uKpgHMkjF_8
# Currently processing video_id: LY0Ll7LRYDI
# Currently processing video_id: lTmJJ3AGizk
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: WG4FIkH6HU8
# Currently processing video_id: DmdcktG7vXM
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: gRb87CBRZ2o
# Currently processing video_id: P0rMYaKFO7k
# Currently processing video_id: igsQae0v0HQ
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: spmAWUn0k40
# Currently processing video_id: jply2m0IoYs
# Currently processing video_id: icGwtYWesWw
# Currently processing video_id: k51hM1cEgcs
# Currently processing video_id: -3Xvyo_-Pyg
# Currently processing video_id: JGP98IDCrTc
# Currently processing video_id: bOppj5rT2xA
# Currently processing video_id: Mz-J5JPxxBI
# Currently processing video_id: RrasC4E_1R8
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: mWacdcatC9o
# Currently processing video_id: BYKz4ksSFFc
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: sRtFQf5wQ-U
# Currently processing video_id: 5VojZY6p798
# Currently processing video_id: qj9REJK5K3w
# Currently processing video_id: 5jrMwhmYW1A
# Currently processing video_id: QdBZY2fkU-0
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: HRfFR2z35hk
# Currently processing video_id: 6MXIRMi1tS8
# Currently processing video_id: ZjrQ11eSsJY
# Currently processing video_id: 9P6xy-AC9Is
# Currently processing video_id: r1R7JgStaBw
# Currently processing video_id: DO3dTP9h6ho
# Currently processing video_id: koGrjBe5kFE
# Currently processing video_id: 3mHwQzN2Po4
# Currently processing video_id: 67rSnZKLef0
# Currently processing video_id: BSop5zkR7KY
# Currently processing video_id: _Q4pcR5H2OE
# Currently processing video_id: iFDN9N-GIrw
# Currently processing video_id: 9AYGP5imeWk
# Currently processing video_id: IMsEt4YBF3Q
# Currently processing video_id: 13DDTAbaL-A
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# Current country :  FR
# Currently processing video_id: bfmUsDJjBkU
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: pIqARNahjJw
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: tfht2Piljo8
# Currently processing video_id: usTqmg0xNZY
# Currently processing video_id: SwlRSu0jjyU
# Currently processing video_id: FrTfxDY2eyI
# Currently processing video_id: NGfpot1_2Is
# Currently processing video_id: W_l0npDNILY
# Currently processing video_id: ziq9BzdRvwY
# Currently processing video_id: TOIAdoDwYYs
# Currently processing video_id: uKpgHMkjF_8
# Currently processing video_id: LY0Ll7LRYDI
# Currently processing video_id: lTmJJ3AGizk
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: WG4FIkH6HU8
# Currently processing video_id: DmdcktG7vXM
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: gRb87CBRZ2o
# Currently processing video_id: P0rMYaKFO7k
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: igsQae0v0HQ
# Currently processing video_id: spmAWUn0k40
# Currently processing video_id: jply2m0IoYs
# Currently processing video_id: icGwtYWesWw
# Currently processing video_id: k51hM1cEgcs
# Currently processing video_id: -3Xvyo_-Pyg
# Currently processing video_id: JGP98IDCrTc
# Currently processing video_id: bOppj5rT2xA
# Currently processing video_id: RrasC4E_1R8
# Currently processing video_id: Mz-J5JPxxBI
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: mWacdcatC9o
# Currently processing video_id: BYKz4ksSFFc
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: sRtFQf5wQ-U
# Currently processing video_id: 5VojZY6p798
# Currently processing video_id: qj9REJK5K3w
# Currently processing video_id: 5jrMwhmYW1A
# Currently processing video_id: QdBZY2fkU-0
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: HRfFR2z35hk
# Currently processing video_id: 6MXIRMi1tS8
# Currently processing video_id: ZjrQ11eSsJY
# Currently processing video_id: 9P6xy-AC9Is
# Currently processing video_id: r1R7JgStaBw
# Currently processing video_id: DO3dTP9h6ho
# Currently processing video_id: koGrjBe5kFE
# Currently processing video_id: 3mHwQzN2Po4
# Currently processing video_id: 67rSnZKLef0
# Currently processing video_id: BSop5zkR7KY
# Currently processing video_id: _Q4pcR5H2OE
# Currently processing video_id: iFDN9N-GIrw
# Currently processing video_id: 9AYGP5imeWk
# Currently processing video_id: IMsEt4YBF3Q
# Currently processing video_id: 13DDTAbaL-A
# Currently processing video_id: bfmUsDJjBkU
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: pIqARNahjJw
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: tfht2Piljo8
# Currently processing video_id: usTqmg0xNZY
# Currently processing video_id: SwlRSu0jjyU
# Currently processing video_id: FrTfxDY2eyI
# Currently processing video_id: NGfpot1_2Is
# Currently processing video_id: W_l0npDNILY
# Currently processing video_id: ziq9BzdRvwY
# Currently processing video_id: TOIAdoDwYYs
# Currently processing video_id: uKpgHMkjF_8
# Currently processing video_id: LY0Ll7LRYDI
# Currently processing video_id: lTmJJ3AGizk
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: WG4FIkH6HU8
# Currently processing video_id: DmdcktG7vXM
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: gRb87CBRZ2o
# Currently processing video_id: P0rMYaKFO7k
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: igsQae0v0HQ
# Currently processing video_id: spmAWUn0k40
# Currently processing video_id: jply2m0IoYs
# Currently processing video_id: icGwtYWesWw
# Currently processing video_id: k51hM1cEgcs
# Currently processing video_id: -3Xvyo_-Pyg
# Currently processing video_id: JGP98IDCrTc
# Currently processing video_id: bOppj5rT2xA
# Currently processing video_id: RrasC4E_1R8
# Currently processing video_id: Mz-J5JPxxBI
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: mWacdcatC9o
# Currently processing video_id: BYKz4ksSFFc
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: sRtFQf5wQ-U
# Currently processing video_id: 5VojZY6p798
# Currently processing video_id: qj9REJK5K3w
# Currently processing video_id: 5jrMwhmYW1A
# Currently processing video_id: QdBZY2fkU-0
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: HRfFR2z35hk
# ...
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: HRfFR2z35hk
# Currently processing video_id: 6MXIRMi1tS8
# Currently processing video_id: ZjrQ11eSsJY
# Currently processing video_id: r1R7JgStaBw
# Currently processing video_id: 9P6xy-AC9Is
# Currently processing video_id: DO3dTP9h6ho
# Currently processing video_id: koGrjBe5kFE
# Currently processing video_id: 67rSnZKLef0
# Currently processing video_id: 3mHwQzN2Po4
# Currently processing video_id: BSop5zkR7KY
# Currently processing video_id: _Q4pcR5H2OE
# Currently processing video_id: iFDN9N-GIrw
# Currently processing video_id: 9AYGP5imeWk
# Currently processing video_id: IMsEt4YBF3Q
# Currently processing video_id: _6YR8xmqEFw
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# Current country :  FR
# Currently processing video_id: bfmUsDJjBkU
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: pIqARNahjJw
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: usTqmg0xNZY
# Currently processing video_id: SwlRSu0jjyU
# Currently processing video_id: tfht2Piljo8
# Currently processing video_id: FrTfxDY2eyI
# Currently processing video_id: NGfpot1_2Is
# Currently processing video_id: W_l0npDNILY
# Currently processing video_id: TOIAdoDwYYs
# Currently processing video_id: LY0Ll7LRYDI
# Currently processing video_id: uKpgHMkjF_8
# Currently processing video_id: ziq9BzdRvwY
# Currently processing video_id: lTmJJ3AGizk
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: WG4FIkH6HU8
# Currently processing video_id: DmdcktG7vXM
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: gRb87CBRZ2o
# Currently processing video_id: P0rMYaKFO7k
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: igsQae0v0HQ
# Currently processing video_id: jply2m0IoYs
# Currently processing video_id: icGwtYWesWw
# Currently processing video_id: spmAWUn0k40
# Currently processing video_id: k51hM1cEgcs
# Currently processing video_id: -3Xvyo_-Pyg
# Currently processing video_id: JGP98IDCrTc
# Currently processing video_id: bOppj5rT2xA
# Currently processing video_id: RrasC4E_1R8
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: Mz-J5JPxxBI
# Currently processing video_id: mWacdcatC9o
# Currently processing video_id: BYKz4ksSFFc
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: sRtFQf5wQ-U
# Currently processing video_id: 5VojZY6p798
# Currently processing video_id: qj9REJK5K3w
# Currently processing video_id: 5jrMwhmYW1A
# Currently processing video_id: QdBZY2fkU-0
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: HRfFR2z35hk
# Currently processing video_id: 6MXIRMi1tS8
# Currently processing video_id: ZjrQ11eSsJY
# Currently processing video_id: r1R7JgStaBw
# Currently processing video_id: 9P6xy-AC9Is
# Currently processing video_id: DO3dTP9h6ho
# Currently processing video_id: koGrjBe5kFE
# Currently processing video_id: 67rSnZKLef0
# Currently processing video_id: 3mHwQzN2Po4
# Currently processing video_id: BSop5zkR7KY
# Currently processing video_id: _Q4pcR5H2OE
# Currently processing video_id: iFDN9N-GIrw
# Currently processing video_id: 9AYGP5imeWk
# Currently processing video_id: IMsEt4YBF3Q
# Currently processing video_id: _6YR8xmqEFw
# Currently processing video_id: bfmUsDJjBkU
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 9RhWXPcKBI8
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: M9p7xS8nKFg
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: pIqARNahjJw
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: usTqmg0xNZY
# Currently processing video_id: SwlRSu0jjyU
# Currently processing video_id: tfht2Piljo8
# Currently processing video_id: FrTfxDY2eyI
# Currently processing video_id: NGfpot1_2Is
# Currently processing video_id: W_l0npDNILY
# Currently processing video_id: TOIAdoDwYYs
# Currently processing video_id: LY0Ll7LRYDI
# Currently processing video_id: uKpgHMkjF_8
# Currently processing video_id: ziq9BzdRvwY
# Currently processing video_id: lTmJJ3AGizk
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: WG4FIkH6HU8
# Currently processing video_id: DmdcktG7vXM
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: gRb87CBRZ2o
# Currently processing video_id: P0rMYaKFO7k
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: igsQae0v0HQ
# Currently processing video_id: jply2m0IoYs
# Currently processing video_id: icGwtYWesWw
# Currently processing video_id: spmAWUn0k40
# Currently processing video_id: k51hM1cEgcs
# Currently processing video_id: -3Xvyo_-Pyg
# Currently processing video_id: JGP98IDCrTc
# Currently processing video_id: bOppj5rT2xA
# Currently processing video_id: RrasC4E_1R8
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: Mz-J5JPxxBI
# Currently processing video_id: mWacdcatC9o
# Currently processing video_id: BYKz4ksSFFc
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: sRtFQf5wQ-U
# Currently processing video_id: 5VojZY6p798
# Currently processing video_id: qj9REJK5K3w
# Currently processing video_id: 5jrMwhmYW1A
# Currently processing video_id: QdBZY2fkU-0
# Currently processing video_id: LnW-DwBrWLk
# Currently processing video_id: 9gAADPMt1FU
# Currently processing video_id: K4GQRiuNpP0
# Currently processing video_id: 6oLB9vDNvI0
# Currently processing video_id: HCJ2WHNpQqc
# Currently processing video_id: pFpjyAp8aJ0
# Currently processing video_id: zePFAZMUnbU
# Currently processing video_id: dh8XxY717Gw
# Currently processing video_id: OBgUnwkPivg
# Currently processing video_id: WB9wpwPVzyY
# Currently processing video_id: aZOiDNzoeWQ
# Currently processing video_id: oByOOqDerrM
# Currently processing video_id: XE_IK7ouDuc
# Currently processing video_id: _Gv62FX9fFc
# Currently processing video_id: F8lPTlpThEo
# Currently processing video_id: EUtsTZK0YuY
# Currently processing video_id: jclw_cAtcIg
# Currently processing video_id: WnBynfbm4e8
# Currently processing video_id: TAKjuokhpyg
# Currently processing video_id: 6X1Ko_TExuM
# Currently processing video_id: YG3EhWlBaoI
# Currently processing video_id: H8xAfHCfrng
# Currently processing video_id: 0VRHcvALBTk
# Currently processing video_id: InIdV5yM1WQ
# Currently processing video_id: 6I5Xg7gz2CM
# Currently processing video_id: xu27rO4j1zc
# Currently processing video_id: Ap7qPHeZcgM
# Currently processing video_id: Rk8rSD1ryeI
# Currently processing video_id: QXFuHrFzeiQ
# Currently processing video_id: vvnlLGFv2mI
# Currently processing video_id: SG065LnQ08Q
# Currently processing video_id: yXuEz2Az0Pw
# Currently processing video_id: FuNLTys8xtQ
# Currently processing video_id: nxZsomptNw0
# Currently processing video_id: CsypIF2PxhU
# Currently processing video_id: AzmDNvoQc0g
# Currently processing video_id: jx2p0Z6ITuA
# Currently processing video_id: X3iJvZNDp9Y
# Currently processing video_id: BOQ1FdoBBmI
# Currently processing video_id: UUYtl783ZS0
# Currently processing video_id: n_Dd7h_7cOM
# Currently processing video_id: 4R7vRFGJr3k
# Currently processing video_id: 6f1Bg-fqBRg
# Currently processing video_id: 7gA9o4myieI
# Currently processing video_id: n4hyVsz7FMA
# Currently processing video_id: HRfFR2z35hk
# Currently processing video_id: 6MXIRMi1tS8
# Currently processing video_id: ZjrQ11eSsJY
# Currently processing video_id: r1R7JgStaBw
# Currently processing video_id: 9P6xy-AC9Is
# Currently processing video_id: DO3dTP9h6ho
# Currently processing video_id: koGrjBe5kFE
# Currently processing video_id: 67rSnZKLef0
# Currently processing video_id: 3mHwQzN2Po4
# Currently processing video_id: BSop5zkR7KY
# Currently processing video_id: _Q4pcR5H2OE
# Currently processing video_id: iFDN9N-GIrw
# Currently processing video_id: 9AYGP5imeWk
# Currently processing video_id: IMsEt4YBF3Q
# Currently processing video_id: _6YR8xmqEFw
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
#          videoId  scanTimestamp      videoExactPublishDate  \
# 0    bfmUsDJjBkU   1.702948e+09  2023-12-17T02:02:00-08:00
# 1    9gAADPMt1FU   1.702948e+09  2023-12-17T10:28:05-08:00
# 2    LnW-DwBrWLk   1.702948e+09  2023-12-17T07:59:59-08:00
# 3    K4GQRiuNpP0   1.702948e+09  2023-12-17T08:00:33-08:00
# 4    aZOiDNzoeWQ   1.702948e+09  2023-12-17T02:17:24-08:00
# ..           ...            ...                        ...
# 107  _Q4pcR5H2OE   1.702971e+09  2023-12-16T01:30:17-08:00
# 108  iFDN9N-GIrw   1.702971e+09  2023-12-16T02:05:05-08:00
# 109  9AYGP5imeWk   1.702971e+09  2023-12-16T07:02:32-08:00
# 110  IMsEt4YBF3Q   1.702971e+09  2023-12-16T09:20:20-08:00
# 111  _6YR8xmqEFw   1.702971e+09  2023-12-17T04:30:10-08:00
#
#     creatorSubscriberNumber  videoTrendsRanking videoLengthSeconds videoType  \
# 0         5.79M subscribers                   0               4585       Now
# 1          724K subscribers                   1               1056       Now
# 2            4M subscribers                   0                827       Now
# 3         1.99M subscribers                   1               2773       Now
# 4         9.19M subscribers                   2               1679       Now
# ..                      ...                 ...                ...       ...
# 107        290K subscribers                  10                 60     Short
# 108        751K subscribers                  11                 60     Short
# 109        321K subscribers                  12                 60     Short
# 110       22.9K subscribers                  13                 42     Short
# 111       78.7K subscribers                  14                 48     Short
#
#      videoCategory trendingCountry  exactViewNumber numberLikes  \
# 0           Comedy              FR  2,489,981 views        183K
# 1           Comedy              FR    325,905 views         57K
# 2           Comedy              FR    492,696 views         39K
# 3    Howto & Style              FR    301,552 views         12K
# 4    Entertainment              FR    979,201 views         63K
# ..             ...             ...              ...         ...
# 107  Entertainment              FR    451,293 views         73K
# 108  Entertainment              FR    684,282 views        Like
# 109  Entertainment              FR    408,654 views         23K
# 110         Gaming              FR    258,762 views         17K
# 111         Sports              FR    118,273 views        5.2K
#
#     numberOfComments  isCreatorVerified  \
# 0               3.1K               True
# 1               1.2K               True
# 2                563               True
# 3                438              False
# 4               1.7K               True
# ..               ...                ...
# 107              613               True
# 108              484               True
# 109               37               True
# 110               33              False
# 111               24              False
#
#                                          videoKeywords  Epoch
# 0    [Mastu, Mastus, Humour, Matsu, loat, mastu enf...      1
# 1                                                  NaN      1
# 2                                                  NaN      1
# 3                                                  NaN      1
# 4         [michou, roue, tournes, souffres, vidéo, Tu]      1
# ..                                                 ...    ...
# 107                                                NaN      7
# 108                                                NaN      7
# 109                                                NaN      7
# 110                                                NaN      7
# 111                                                NaN      7
#
# [785 rows x 15 columns]

# %%
df=pd.read_csv('Dataset_0.csv')
df.head(2)
# Out:
#    Unnamed: 0      videoId  scanTimestamp      videoExactPublishDate  \
# 0           0  bfmUsDJjBkU   1.702948e+09  2023-12-17T02:02:00-08:00
# 1           1  9gAADPMt1FU   1.702948e+09  2023-12-17T10:28:05-08:00
#
#   creatorSubscriberNumber  videoTrendsRanking  videoLengthSeconds videoType  \
# 0       5.79M subscribers                   0                4585       Now
# 1        724K subscribers                   1                1056       Now
#
#   videoCategory trendingCountry  exactViewNumber numberLikes numberOfComments  \
# 0        Comedy              FR  2,489,981 views        183K             3.1K
# 1        Comedy              FR    325,905 views         57K             1.2K
#
#    isCreatorVerified                                      videoKeywords  Epoch
# 0               True  ['Mastu', 'Mastus', 'Humour', 'Matsu', 'loat',...      1
# 1               True                                                NaN      1

# %%
def pooling_data(n_scans,start_name='Dataset_'):
    dataset_pooled=pd.concat([pd.read_csv(start_name+'{}.csv'.format(i)) for i in range(n_scans)])
    return dataset_pooled

# %%
full_dataset=pooling_data(7)
full_dataset.head(2)
full_dataset.columns
full_dataset['Epoch'].unique()
full_dataset.to_csv('Poling_dataset.csv')

# %%
# Out:
# 'Dataset_1'

# %%
for i in range(2,7):
    #df_name='Dataset_{i}'.format(i)
    df=pd.read_csv("Dataset_{i}.csv")
    #current_dataset=globals()[df_name]
    print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 3
#       1 for i in range(2,7):
#       2     #df_name='Dataset_{i}'.format(i)
# ----> 3     df=pd.read_csv("Dataset_{i}.csv")
#       4     #current_dataset=globals()[df_name]
#       5     print(df.shape)
#
# File /opt/mamba/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /opt/mamba/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /opt/mamba/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /opt/mamba/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File /opt/mamba/lib/python3.10/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dataset_{i}.csv'

# %%
for i in range(7):
    print(i)
    name='Dataset_{}.csv'.format(i)
    print(name)
    print(pd.read_csv(name).shape)
    pd.read_csv(name).to_csv(
# Out:
# 0
# Dataset_0.csv
# (113, 16)
# 1
# Dataset_1.csv
# (112, 16)
# 2
# Dataset_2.csv
# (112, 16)
# 3
# Dataset_3.csv
# (112, 16)
# 4
# Dataset_4.csv
# (112, 16)
# 5
# Dataset_5.csv
# (112, 16)
# 6
# Dataset_6.csv
# (112, 16)

# %%
n_scans=7
filepaths=[ ' ' for i in range(n_scans)]
for i in range(n_scans):
    print(i)
    filepaths[i]='C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_{}.csv'.format(i)
    print(filepaths[i])
# Out:
# 0
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_0.csv
# 1
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_1.csv
# 2
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_2.csv
# 3
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_3.csv
# 4
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_4.csv
# 5
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_5.csv
# 6
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_6.csv

# %%
df_test2=pd.DataFrame(np.zeros((2,5)))
df_test2
df_test2.to_csv('C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/df_test2.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[65], line 3
#       1 df_test2=pd.DataFrame(np.zeros((2,5)))
#       2 df_test2
# ----> 3 df_test2.to_csv('C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/df_test2.csv')
#
# File /opt/mamba/lib/python3.10/site-packages/pandas/core/generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File /opt/mamba/lib/python3.10/site-packages/pandas/io/formats/format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File /opt/mamba/lib/python3.10/site-packages/pandas/io/formats/csvs.py:247, in CSVFormatter.save(self)
#     243 """
#     244 Create the writer & save.
#     245 """
#     246 # apply compression and byte/text conversion
# --> 247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#     250     encoding=self.encoding,
#     251     errors=self.errors,
#     252     compression=self.compression,
#     253     storage_options=self.storage_options,
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
#     266     self._save()
#
# File /opt/mamba/lib/python3.10/site-packages/pandas/io/common.py:739, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     737 # Only for write methods
#     738 if "r" not in mode and is_path:
# --> 739     check_parent_directory(str(handle))
#     741 if compression:
#     742     if compression != "zstd":
#     743         # compression libraries do not like an explicit text-mode
#
# File /opt/mamba/lib/python3.10/site-packages/pandas/io/common.py:604, in check_parent_directory(path)
#     602 parent = Path(path).parent
#     603 if not parent.is_dir():
# --> 604     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data'

# %%
import requests
import time
import numpy as np
import pandas as pd
import copy

# %%
def post_request_ytb(country_code_list, trending_type_dict):
    responses_dict = {}
    for country_code in country_code_list:
        responses_dict[country_code] = {}
        for trending_type, trending_type_url in trending_type_dict.items():
            json_data = {
                'context': {
                    'client': {
                        'gl': country_code,
                        'clientName': 'WEB',
                        'clientVersion': '2.20231115.01.01',
                        'originalUrl': 'https://www.youtube.com/feed/trending',
                    },
                },
                'browseId': 'FEtrending',
                'params': trending_type_url,
            }

            response = requests.post(
                'https://www.youtube.com/youtubei/v1/browse',
                json=json_data,
            )
            responses_dict[country_code][trending_type] = response.json()
    return responses_dict

# %%
def post_request_ytb(country_code_list, trending_type_dict):
    responses_dict = {}
    for country_code in country_code_list:
        responses_dict[country_code] = {}
        for trending_type, trending_type_url in trending_type_dict.items():
            json_data = {
                'context': {
                    'client': {
                        'gl': country_code,
                        'clientName': 'WEB',
                        'clientVersion': '2.20231115.01.01',
                        'originalUrl': 'https://www.youtube.com/feed/trending',
                    },
                },
                'browseId': 'FEtrending',
                'params': trending_type_url,
            }

            response = requests.post(
                'https://www.youtube.com/youtubei/v1/browse',
                json=json_data,
            )
            responses_dict[country_code][trending_type] = response.json()
    return responses_dict

# %%
def post_request_ytb(country_code_list, trending_type_dict):
    responses_dict = {}
    for country_code in country_code_list:
        responses_dict[country_code] = {}
        for trending_type, trending_type_url in trending_type_dict.items():
            json_data = {
                'context': {
                    'client': {
                        'gl': country_code,
                        'clientName': 'WEB',
                        'clientVersion': '2.20231115.01.01',
                        'originalUrl': 'https://www.youtube.com/feed/trending',
                    },
                },
                'browseId': 'FEtrending',
                'params': trending_type_url,
            }

            response = requests.post(
                'https://www.youtube.com/youtubei/v1/browse',
                json=json_data,
            )
            responses_dict[country_code][trending_type] = response.json()
    return responses_dict

# %%
def post_request_ytb(country_code_list, trending_type_dict):
    responses_dict = {}
    for country_code in country_code_list:
        responses_dict[country_code] = {}
        for trending_type, trending_type_url in trending_type_dict.items():
            json_data = {
                'context': {
                    'client': {
                        'gl': country_code,
                        'clientName': 'WEB',
                        'clientVersion': '2.20231115.01.01',
                        'originalUrl': 'https://www.youtube.com/feed/trending',
                    },
                },
                'browseId': 'FEtrending',
                'params': trending_type_url,
            }

            response = requests.post(
                'https://www.youtube.com/youtubei/v1/browse',
                json=json_data,
            )
            responses_dict[country_code][trending_type] = response.json()
    return responses_dict

# %%
def collect_video_data(video_list, data_dictionary, trending_type, country_code, current_timestamp):
    # Collect data (generic videos) INPLACE
    nb_items = len(video_list)
    data_dictionary["videoId"] += [video_list[k]["videoRenderer"]["videoId"] for k in range(nb_items)]
    data_dictionary["videoType"] += [trending_type for k in range(nb_items)]
    data_dictionary["trendingCountry"] += [country_code for k in range(nb_items)]
    data_dictionary["videoTrendsRanking"] += [k for k in range(nb_items)]
    data_dictionary["scanTimeStamp"] += [current_timestamp for k in range(nb_items)]
    return None

# %%
def collect_short_data(shorts_list, data_dictionary, country_code, current_timestamp):
    # Collect data (generic videos) INPLACE
    nb_items = len(shorts_list)
    data_dictionary["videoId"] += [shorts_list[k]["reelItemRenderer"]["videoId"] for k in range(nb_items)]
    data_dictionary["videoType"] += ['Short' for k in range(nb_items)]
    data_dictionary["trendingCountry"] += [country_code for k in range(nb_items)]
    data_dictionary["videoTrendsRanking"] += [k for k in range(nb_items)]
    data_dictionary["scanTimeStamp"] += [current_timestamp for k in range(nb_items)]
    return None

# %%
def add_now_videos_shorts(response_dict, data_dictionary, current_timestamp):
    # Update data_dictionary with "Now", "Recently Trending" and "Shorts" videos data INPLACE
    for country_code in response_dict.keys():
        print("Current country : ", country_code)
        section_now = response_dict[country_code]['Now']["contents"]["twoColumnBrowseResultsRenderer"]["tabs"][0]["tabRenderer"]["content"]["sectionListRenderer"]["contents"]
        try:
            list_videos_before = section_now[0]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
            shorts_list = section_now[1]["itemSectionRenderer"]["contents"][0]["reelShelfRenderer"]["items"]
            list_videos_after = section_now[2]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
            list_videos_recently = section_now[3]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
        except KeyError:
            list_videos_before = section_now[1]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
            shorts_list = section_now[2]["itemSectionRenderer"]["contents"][0]["reelShelfRenderer"]["items"]
            list_videos_after = section_now[3]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
            list_videos_recently = section_now[4]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
        collect_video_data(list_videos_before, data_dictionary, 'Now', country_code, current_timestamp)
        collect_video_data(list_videos_after, data_dictionary, 'Now', country_code, current_timestamp)
        collect_video_data(list_videos_recently, data_dictionary, 'Recently Trending', country_code, current_timestamp)
        collect_short_data(shorts_list, data_dictionary, country_code, current_timestamp)
    return None

# %%
def add_other_sections(response_dict, data_dictionary, current_timestamp):
    # Update data_dictionary with "Music", "Gaming", "Movies" videos data INPLACE
    for country_code in response_dict.keys():
        for idx, key in enumerate(response_dict[country_code].keys()): # in recent Python versions, dictionary are ordered
            if idx != 0:
                sections = response_dict[country_code][key]["contents"]["twoColumnBrowseResultsRenderer"]["tabs"][idx]["tabRenderer"]["content"]["sectionListRenderer"]["contents"]
                video_list = sections[0]["itemSectionRenderer"]["contents"][0]["shelfRenderer"]["content"]["expandedShelfContentsRenderer"]["items"]
                collect_video_data(video_list, data_dictionary, key, country_code, current_timestamp)
    return None

# %%
def update_video_data(data_dictionary):
    # Update data for individual videos in data_dictionary INPLACE
    for video_id in data_dictionary["videoId"]:
        print("Currently processing video_id:", video_id)
        json_data = {
            'context': {
                'client': {
                    'clientName': 'WEB',
                    'clientVersion': '2.20231208.01.00',            
                    }
            },
            'videoId': video_id,
        }
        
        response = requests.post('https://www.youtube.com/youtubei/v1/next', json=json_data)
        video_response = response.json()
        individual_video_data = video_response["contents"]["twoColumnWatchNextResults"]["results"]["results"]["contents"]
        data_dictionary["exactViewNumber"].append(individual_video_data[0]["videoPrimaryInfoRenderer"]["viewCount"]["videoViewCountRenderer"]["viewCount"]["simpleText"])
        data_dictionary["numberLikes"].append(individual_video_data[0]["videoPrimaryInfoRenderer"]["videoActions"]["menuRenderer"]["topLevelButtons"][0]["segmentedLikeDislikeButtonViewModel"]["likeButtonViewModel"]["likeButtonViewModel"]["toggleButtonViewModel"]["toggleButtonViewModel"]["defaultButtonViewModel"]["buttonViewModel"]["title"])
        data_dictionary["creatorSubscriberNumber"].append(individual_video_data[1]["videoSecondaryInfoRenderer"]["owner"]["videoOwnerRenderer"]["subscriberCountText"]["simpleText"])     
        try:    
            data_dictionary["numberOfComments"].append(individual_video_data[2]["itemSectionRenderer"]["contents"][0]["commentsEntryPointHeaderRenderer"]["commentCount"]["simpleText"])
        except KeyError: # correct for additional "merchandise" section
            try:
                data_dictionary["numberOfComments"].append(individual_video_data[3]["itemSectionRenderer"]["contents"][0]["commentsEntryPointHeaderRenderer"]["commentCount"]["simpleText"])
            except IndexError: # comments are turned off
                data_dictionary["numberOfComments"].append(np.nan)
        try:
            data_dictionary["isCreatorVerified"].append(individual_video_data[1]["videoSecondaryInfoRenderer"]["owner"]["videoOwnerRenderer"]["badges"][0]["metadataBadgeRenderer"]["tooltip"] == "Verified")
        except KeyError:
            data_dictionary["isCreatorVerified"].append(False)    
        time.sleep(1)
    return None

# %%
def update_meta_data(data_dictionary):
    # Update metadata for individual videos in data_dictionary INPLACE
    for video_id in data_dictionary["videoId"]:
        print("Currently processing video_id:", video_id)
        json_data = {
        'context': {
            'client': {
                'clientName': 'WEB',
                'clientVersion': '2.20231208.01.00',
            },
        },
        'videoId': video_id,
        }
        
        response = requests.post('https://www.youtube.com/youtubei/v1/player', json=json_data)
        
        meta_response = response.json()
        try:
            data_dictionary["videoKeywords"].append(meta_response["videoDetails"]["keywords"])
        except KeyError: # no keywords
            data_dictionary["videoKeywords"].append(np.nan)
        data_dictionary["videoLengthSeconds"].append(meta_response["videoDetails"]["lengthSeconds"])
        data_dictionary["videoCategory"].append(meta_response["microformat"]["playerMicroformatRenderer"]["category"])
        data_dictionary["videoExactPublishDate"].append(meta_response["microformat"]["playerMicroformatRenderer"]["uploadDate"])
        time.sleep(1)
    return None

# %%
TRENDING_TYPE_DICT = {
    'Now': None,
    # 'Music': '4gINGgt5dG1hX2NoYXJ0cw%3D%3D',
    # 'Gaming': '4gIcGhpnYW1pbmdfY29ycHVzX21vc3RfcG9wdWxhcg%3D%3D',
    # 'Movie': '4gIKGgh0cmFpbGVycw%3D%3D',
}

FRENCH_COUNTRY_DICT = ['FR']

# %%
def scan_trending_ytb(n_scans=5, delta_scans=1800):
    """

    Args:
        n_scans (_type_): nombre de fois ou les tendances sont scannees
        delta_scans (_type_): delai entre deux scans des tendances (en secondes)
        
    """
    data_dictionary = {
    'videoId': [],
    'scanTimeStamp': [],
    'videoExactPublishDate': [],
    'creatorSubscriberNumber': [],
    'videoTrendsRanking': [],
    'videoLengthSeconds': [],
    'videoType': [],
    'videoCategory': [],
    'trendingCountry': [],
    'exactViewNumber': [],
    'numberLikes': [],
    'numberOfComments': [],
    'isCreatorVerified': [],
    'videoKeywords': []
}
    data_dictionary_panel = [copy.deepcopy(data_dictionary) for k in range(n_scans)]
    Epoches=["Epoch" for k in range(n_scans)] #cette colonne supplémentaire définit pour chaque ligne, l'époque-un entier- à laquelle elle a été scappé
    les_tailles=np.zeros(n_scans,dtype=int) #ce tableau 1D  contient pour chaque Dataframe scappé, le nombre de ligne du Dataframe
    for scan in range(n_scans):
        current_timestamp = time.time()
        response_dict = post_request_ytb(FRENCH_COUNTRY_DICT, TRENDING_TYPE_DICT)
        add_now_videos_shorts(response_dict, data_dictionary_panel[scan], current_timestamp)
        add_other_sections(response_dict, data_dictionary_panel[scan], current_timestamp)
        update_video_data(data_dictionary_panel[scan])
        update_meta_data(data_dictionary_panel[scan])
        for k in data_dictionary_panel[scan].keys():
            print(len(data_dictionary_panel[scan][k]))
            les_tailles[scan]=int(len(data_dictionary_panel[scan][k]))
        time.sleep(delta_scans)
        #cles_zero=cles[0]
        #n=data_dictionary_panel[scan][cles_zero].shape[0]
        n=les_tailles[scan]
        data_dictionary_panel[scan][Epoches[scan]]=np.full(n,scan+1)
        # aprés chaque collecte, on met le résultats dans un datframe 
        pd.DataFrame(data_dictionary_panel[scan]).to_csv('Dataset_{}.csv'.format(scan))

    return pd.concat([pd.DataFrame(lst) for lst in data_dictionary_panel])

# %%
#le code ci dessous, nous a permis de collecter 7 fois les vidéos en tendances pour des intervalles de temps de collecte d'1h= 60*60=3600 seconde

# %%
scan_trending_ytb(7,3600)

# %%
# Out:
#          videoId  scanTimestamp      videoExactPublishDate  \
# 0    bfmUsDJjBkU   1.702948e+09  2023-12-17T02:02:00-08:00
# 1    9gAADPMt1FU   1.702948e+09  2023-12-17T10:28:05-08:00
# 2    LnW-DwBrWLk   1.702948e+09  2023-12-17T07:59:59-08:00
# 3    K4GQRiuNpP0   1.702948e+09  2023-12-17T08:00:33-08:00
# 4    aZOiDNzoeWQ   1.702948e+09  2023-12-17T02:17:24-08:00
# ..           ...            ...                        ...
# 107  _Q4pcR5H2OE   1.702971e+09  2023-12-16T01:30:17-08:00
# 108  iFDN9N-GIrw   1.702971e+09  2023-12-16T02:05:05-08:00
# 109  9AYGP5imeWk   1.702971e+09  2023-12-16T07:02:32-08:00
# 110  IMsEt4YBF3Q   1.702971e+09  2023-12-16T09:20:20-08:00
# 111  _6YR8xmqEFw   1.702971e+09  2023-12-17T04:30:10-08:00
#
#     creatorSubscriberNumber  videoTrendsRanking  videoLengthSeconds videoType  \
# 0         5.79M subscribers                   0                4585       Now
# 1          724K subscribers                   1                1056       Now
# 2            4M subscribers                   0                 827       Now
# 3         1.99M subscribers                   1                2773       Now
# 4         9.19M subscribers                   2                1679       Now
# ..                      ...                 ...                 ...       ...
# 107        290K subscribers                  10                  60     Short
# 108        751K subscribers                  11                  60     Short
# 109        321K subscribers                  12                  60     Short
# 110       22.9K subscribers                  13                  42     Short
# 111       78.7K subscribers                  14                  48     Short
#
#      videoCategory trendingCountry  exactViewNumber numberLikes  \
# 0           Comedy              FR  2,489,981 views        183K
# 1           Comedy              FR    325,905 views         57K
# 2           Comedy              FR    492,696 views         39K
# 3    Howto & Style              FR    301,552 views         12K
# 4    Entertainment              FR    979,201 views         63K
# ..             ...             ...              ...         ...
# 107  Entertainment              FR    451,293 views         73K
# 108  Entertainment              FR    684,282 views        Like
# 109  Entertainment              FR    408,654 views         23K
# 110         Gaming              FR    258,762 views         17K
# 111         Sports              FR    118,273 views        5.2K
#
#     numberOfComments  isCreatorVerified  \
# 0               3.1K               True
# 1               1.2K               True
# 2                563               True
# 3                438              False
# 4               1.7K               True
# ..               ...                ...
# 107              613               True
# 108              484               True
# 109               37               True
# 110               33              False
# 111               24              False
#
#                                          videoKeywords  Epoch
# 0    ['Mastu', 'Mastus', 'Humour', 'Matsu', 'loat',...      1
# 1                                                  NaN      1
# 2                                                  NaN      1
# 3                                                  NaN      1
# 4    ['michou', 'roue', 'tournes', 'souffres', 'vid...      1
# ..                                                 ...    ...
# 107                                                NaN      7
# 108                                                NaN      7
# 109                                                NaN      7
# 110                                                NaN      7
# 111                                                NaN      7
#
# [785 rows x 15 columns]

# %%
n_scans=7
filepaths=[ ' ' for i in range(n_scans)]
for i in range(n_scans):
    print(i)
    filepaths[i]='/data/data_batch_{}.csv'.format(i)
    print(filepaths[i])

# %%
pd.read_csv("/Users/jbrable/Documents/ENSAE_3A/S1/isl/YouTrend/data/FR_20240105_trends.csv")
# Out:
#      Unnamed: 0                                         videoTitle  \
# 0             0  JOUR 2 pour Survivre sur une ile déserte (GTA ...
# 1             1        Survivre sur une ile déserte (GTA RP ! # 1)
# 2             2  Le dernier qui dort gagne (dans un magasin de ...
# 3             3  200 SECRETS sur MINECRAFT (t'en connais combie...
# 4             4                    Je t'aime comme ça👌- Seb Mellia
# ..          ...                                                ...
# 217         217  Beverly Hills Cop: Axel F | Official Teaser Tr...
# 218         218           LAND OF BAD Trailer (2024) Russell Crowe
# 219         219  Indian Police Force Season 1 - Official Traile...
# 220         220  Bambaşka Biri 15. Bölüm 2. Fragmanı | Seni Çok...
# 221         221  Salaar Release Trailer - Hindi | Prabhas | Pra...
#
#          videoId                                  videoThumbnailUrl  \
# 0    mWIxKzXGWzA  https://i.ytimg.com/vi/mWIxKzXGWzA/hqdefault.j...
# 1    r7Bnj7--cUY  https://i.ytimg.com/vi/r7Bnj7--cUY/hqdefault.j...
# 2    3ntq3aT_454  https://i.ytimg.com/vi/3ntq3aT_454/hqdefault.j...
# 3    FPBfGbw2w-Y  https://i.ytimg.com/vi/FPBfGbw2w-Y/hqdefault.j...
# 4    aKX9xq_cJUk  https://i.ytimg.com/vi/aKX9xq_cJUk/hqdefault.j...
# ..           ...                                                ...
# 217  qBG3iyr5N70  https://i.ytimg.com/vi/qBG3iyr5N70/hqdefault.j...
# 218  95eJpJlBfUs  https://i.ytimg.com/vi/95eJpJlBfUs/hqdefault.j...
# 219  6Jr4lNiK6XE  https://i.ytimg.com/vi/6Jr4lNiK6XE/hqdefault.j...
# 220  Nc9RfRhqJhY  https://i.ytimg.com/vi/Nc9RfRhqJhY/hqdefault.j...
# 221  Pr2jBvbiy04  https://i.ytimg.com/vi/Pr2jBvbiy04/hqdefault.j...
#
#                                videoDescriptionSnippet  \
# 0    🎥 Chaîne secondaire : https://inoxtag.tv/inoxt...
# 1    Profitez de l'offre -15% avec le code "INOXTAG...
# 2    C'est clairement l'épisode le plus dur de la s...
# 3    15 ans après sa sortie, Minecraft est le jeu l...
# 4    Des couples parfaits, et un amour comme ca 👌\n...
# ..                                                 ...
# 217  Detective Axel Foley (Eddie Murphy) is back on...
# 218  LAND OF BAD Trailer (2024) Russell Crowe, Liam...
# 219  Prime Video India Presents\nIndian Police Forc...
# 220  Bambaşka Biri 15. Bölüm 2. Fragmanı | Seni Çok...
# 221  Salaar Releasing on December 22nd 2023 \nBook ...
#
#     videoRelativePublishedTimeText videoLength videoViewCountText  \
# 0            Streamed 18 hours ago     5:41:07    1,040,386 views
# 1               Streamed 1 day ago     4:04:59    1,570,964 views
# 2                        1 day ago       39:17      280,156 views
# 3                        1 day ago       20:21      229,110 views
# 4                     13 hours ago       20:53       65,130 views
# ..                             ...         ...                ...
# 217                    3 weeks ago        1:34   23,589,396 views
# 218                    2 weeks ago        2:32    1,758,474 views
# 219                   10 hours ago        3:02   17,466,393 views
# 220                    4 hours ago        0:42      120,365 views
# 221                    2 weeks ago        2:54   61,474,672 views
#
#       videoCreatorName videoType  ...  \
# 0              Inoxtag       Now  ...
# 1              Inoxtag       Now  ...
# 2         Lucas Studio       Now  ...
# 3      Trash Bandicoot       Now  ...
# 4            SebMellia       Now  ...
# ..                 ...       ...  ...
# 217            Netflix     Movie  ...
# 218          ONE Media     Movie  ...
# 219  Prime Video India     Movie  ...
# 220      Bambaşka Biri     Movie  ...
# 221      Hombale Films     Movie  ...
#
#                                videoVerboseDescription numberOfComments  \
# 0    🎥 Chaîne secondaire : https://inoxtag.tv/inoxt...              485
# 1    Profitez de l'offre -15% avec le code "INOXTAG...              801
# 2    C'est clairement l'épisode le plus dur de la s...              207
# 3    15 ans après sa sortie, Minecraft est le jeu l...              362
# 4    Des couples parfaits, et un amour comme ca 👌\n...              131
# ..                                                 ...              ...
# 217  Detective Axel Foley (Eddie Murphy) is back on...              11K
# 218  LAND OF BAD Trailer (2024) Russell Crowe, Liam...             1.4K
# 219  Prime Video India Presents\nIndian Police Forc...              12K
# 220  Bambaşka Biri 15. Bölüm 2. Fragmanı | Seni Çok...              207
# 221  Salaar Releasing on December 22nd 2023 \nBook ...              29K
#
#     isCreatorVerified                                      videoKeywords  \
# 0                True     ['INOXTAG', 'INOX', 'CROUTON', 'live inoxtag']
# 1                True     ['INOXTAG', 'INOX', 'CROUTON', 'live inoxtag']
# 2                True  ['lucas studio', 'le dernier qui dort', 'le de...
# 3                True  ['Jeux vidéo', 'Jeu vidéo', 'Gaming', 'Game', ...
# 4                True  ['Seb Mellia', 'Humour', 'stand up', 'sketch',...
# ..                ...                                                ...
# 217              True  ['2024 Movie Trailers', 'Axel Foley', 'Bronson...
# 218              True  ['One Media', 'Trailer', 'Official', 'Movie', ...
# 219              True  ['indian police force', 'indian police force t...
# 220             False  ['timsb', 'TIMSB', 'Bambaşka Biri', 'Bambaşka ...
# 221              True  ['Hombale films', 'hombale films channel', 'ho...
#
#     videoLengthSeconds videoIsLiveContent     videoCategory  isFamilySafe  \
# 0                20467               True            Gaming          True
# 1                14698               True            Gaming          True
# 2                 2356              False            Comedy          True
# 3                 1221              False            Gaming          True
# 4                 1253              False            Comedy          True
# ..                 ...                ...               ...           ...
# 217                 94              False     Entertainment          True
# 218                152              False  Film & Animation          True
# 219                182              False     Entertainment          True
# 220                 42              False     Entertainment          True
# 221                174              False  Film & Animation          True
#
#          videoExactPublishDate                                creatorUrl
# 0    2024-01-04T18:04:39-08:00           http://www.youtube.com/@inoxtag
# 1    2024-01-03T15:30:40-08:00           http://www.youtube.com/@inoxtag
# 2    2024-01-04T09:17:33-08:00      http://www.youtube.com/@lucas_studio
# 3    2024-01-04T10:15:09-08:00    http://www.youtube.com/@trashbandicoot
# 4    2024-01-04T22:30:00-08:00         http://www.youtube.com/@SebMellia
# ..                         ...                                       ...
# 217  2023-12-14T05:28:08-08:00           http://www.youtube.com/@Netflix
# 218  2023-12-19T10:06:37-08:00         http://www.youtube.com/@OneMedia.
# 219  2024-01-05T01:19:14-08:00      http://www.youtube.com/@PrimeVideoIN
# 220  2024-01-05T07:38:00-08:00  http://www.youtube.com/@bambaskabiridizi
# 221  2023-12-18T02:03:00-08:00      http://www.youtube.com/@HombaleFilms
#
# [222 rows x 25 columns]

# %%
pd.read_csv("/Users/jbrable/Documents/ENSAE_3A/S1/isl/YouTrend/data/FR_20240105_trends.csv")
# Out:
#      Unnamed: 0                                         videoTitle  \
# 0             0  Qui Aura Le Plat Piégé ? (Ft. Inoxtag , Gurky ...
# 1             1               ZOLA x KOBA LA D - ALLER SANS RETOUR
# 2             2  JuL - La Fusion ft. Alonzo // Clip Officiel //...
# 3             3   J’EXPLORE MA PREMIÈRE GROTTE ! 😍 (Fortnite Lego)
# 4             4  J'ai paumé ma femme et mon gosse ! - LE MONDE ...
# ..          ...                                                ...
# 216         216  Neru - Official Trailer | Mohanlal | Jeethu Jo...
# 217         217  Ömer 35. Bölüm 2. Fragmanı | Siz Gamze'siz Bir...
# 218         218             「ドラゴンボール Sparking! ZERO」 アナウンスメントトレーラー
# 219         219             Ne Gemiler Yaktım 2. Bölüm 2. Fragmanı
# 220         220                        Safir 14. Bölüm 2. Fragmanı
#
#          videoId                                  videoThumbnailUrl  \
# 0    zePFAZMUnbU  https://i.ytimg.com/vi/zePFAZMUnbU/hqdefault.j...
# 1    F8lPTlpThEo  https://i.ytimg.com/vi/F8lPTlpThEo/hqdefault.j...
# 2    WB9wpwPVzyY  https://i.ytimg.com/vi/WB9wpwPVzyY/hqdefault.j...
# 3    P4hkzfYaz3Q  https://i.ytimg.com/vi/P4hkzfYaz3Q/hqdefault.j...
# 4    0_9I9Jn_YGE  https://i.ytimg.com/vi/0_9I9Jn_YGE/hqdefault.j...
# ..           ...                                                ...
# 216  abuLOH7xs8I  https://i.ytimg.com/vi/abuLOH7xs8I/hqdefault.j...
# 217  OjEk0pQfZus  https://i.ytimg.com/vi/OjEk0pQfZus/hqdefault.j...
# 218  UWCm-vSxcKE  https://i.ytimg.com/vi/UWCm-vSxcKE/hqdefault.j...
# 219  oWvpGJFljiA  https://i.ytimg.com/vi/oWvpGJFljiA/hqdefault.j...
# 220  BF4WQpYVsr0  https://i.ytimg.com/vi/BF4WQpYVsr0/hqdefault.j...
#
#                                videoDescriptionSnippet  \
# 0    Inoxtag, Gurky et Nico : Qui aura le plat piég...
# 1    Single  "Aller Sans Retour" maintenant disponi...
# 2    JuL - Nouvel album '' La route est longue '' d...
# 3    Salut ! Aujourd'hui nouvelle vidéo, j'espère q...
# 4    J'ai fini par le trouver moi aussi... Désolé N...
# ..                                                 ...
# 216  Presenting the official trailer of NERU\n\n#Ne...
# 217  Ömer 35. Bölüm 2. Fragmanı | Siz Gamze'siz Bir...
# 218  「ドラゴンボールZ Sparking!」シリーズ最新作――\n「ドラゴンボール Sparki...
# 219  Ne Gemiler Yaktım 2. Bölüm 2. Fragman\n\nHer P...
# 220  Safir 14. Bölüm 2. Fragmanı\nSafir 4 Aralık Pa...
#
#     videoRelativePublishedTimeText videoLength videoViewCountText  \
# 0                        1 day ago       38:35    1,103,128 views
# 1                        1 day ago        3:23      522,502 views
# 2                        1 day ago        3:50    1,085,667 views
# 3                        1 day ago       19:55      574,835 views
# 4                        1 day ago       12:46      323,580 views
# ..                             ...         ...                ...
# 216                      1 day ago        2:17    1,487,941 views
# 217                      1 day ago        1:14      367,408 views
# 218                     2 days ago        1:03      390,030 views
# 219                      1 day ago        1:03      296,944 views
# 220                     8 days ago        0:45      735,496 views
#
#                videoCreatorName videoType  ...  \
# 0               FastGoodCuisine       Now  ...
# 1                          Zola       Now  ...
# 2                DORETDEPLATINE       Now  ...
# 3                     MichouOff       Now  ...
# 4                          MATH       Now  ...
# ..                          ...       ...  ...
# 216           Aashirvad Cinemas     Movie  ...
# 217                 Ömer Dizisi     Movie  ...
# 218  Bandai Namco Entertainment     Movie  ...
# 219           Ne Gemiler Yaktım     Movie  ...
# 220                   NTC MEDYA     Movie  ...
#
#                                videoVerboseDescription numberOfComments  \
# 0    Inoxtag, Gurky et Nico : Qui aura le plat piég...              620
# 1    Single  "Aller Sans Retour" maintenant disponi...             1.2K
# 2    JuL - Nouvel album '' La route est longue '' d...              796
# 3    Salut ! Aujourd'hui nouvelle vidéo, j'espère q...              596
# 4    J'ai fini par le trouver moi aussi... Désolé N...              494
# ..                                                 ...              ...
# 216  Presenting the official trailer of NERU\n\n#Ne...             6.4K
# 217  Ömer 35. Bölüm 2. Fragmanı | Siz Gamze'siz Bir...              603
# 218  「ドラゴンボールZ Sparking!」シリーズ最新作――\n「ドラゴンボール Sparki...              NaN
# 219  Ne Gemiler Yaktım 2. Bölüm 2. Fragman\n\nHer P...              141
# 220  Safir 14. Bölüm 2. Fragmanı\nSafir 4 Aralık Pa...              498
#
#     isCreatorVerified                                      videoKeywords  \
# 0                True  ['Fastgoodcuisine', 'Fastgood', 'Fastfood', 'Q...
# 1               False  ['Zola', 'Koba', 'Koba Ła D', 'Kobalad', 'zola...
# 2                True  ['JuL', 'Alonzo', 'La fusion', 'Clip Officiel'...
# 3                True  ['michou', 'michouoff', 'off', 'best of', 'vid...
# 4                True  ['finding nemo', 'nemo', 'dory', 'le monde de ...
# ..                ...                                                ...
# 216              True  ['Neru', 'Neru movie', 'neru movie malayalam',...
# 217             False  ['OGM Pictures', 'star tv', 'ömer dizisi', 'öm...
# 218              True  ['バンダイナムコ', 'バンナム', '876', '876TV', 'BNE', 'バン...
# 219             False  ['ne gemiler yaktım', 'ay yapım', 'show tv', '...
# 220              True  ['ntc medya', 'atv', 'safir', 'İlhan Şen', 'Öz...
#
#     videoLengthSeconds videoIsLiveContent     videoCategory  isFamilySafe  \
# 0                 2314              False     Howto & Style          True
# 1                  203              False             Music          True
# 2                  229              False             Music          True
# 3                 1194              False            Gaming          True
# 4                  765              False            Comedy          True
# ..                 ...                ...               ...           ...
# 216                137              False  Film & Animation          True
# 217                 74              False     Entertainment          True
# 218                 62              False            Gaming          True
# 219                 62              False     Entertainment          True
# 220                 44              False     Entertainment          True
#
#          videoExactPublishDate  \
# 0    2023-12-08T09:18:08-08:00
# 1    2023-12-08T09:01:00-08:00
# 2    2023-12-08T09:00:37-08:00
# 3    2023-12-09T02:15:03-08:00
# 4    2023-12-08T08:59:47-08:00
# ..                         ...
# 216  2023-12-09T03:30:11-08:00
# 217  2023-12-08T09:46:04-08:00
# 218  2023-12-07T18:58:18-08:00
# 219  2023-12-08T07:49:42-08:00
# 220  2023-12-01T13:05:41-08:00
#
#                                            creatorUrl
# 0             http://www.youtube.com/@FastGoodCuisine
# 1                    http://www.youtube.com/@zola5047
# 2                http://www.youtube.com/@julsaintjean
# 3                   http://www.youtube.com/@MichouOff
# 4          http://www.youtube.com/@MathSeFaitDesFilms
# ..                                                ...
# 216  http://www.youtube.com/@AashirvadCinemasOfficial
# 217             http://www.youtube.com/@OmerDiziResmi
# 218  http://www.youtube.com/@bandainamcoentertainment
# 219       http://www.youtube.com/@NeGemilerYaktimDizi
# 220                http://www.youtube.com/@NTCMedyaTV
#
# [221 rows x 25 columns]

# %%
df=pd.read_csv('data/train_sample.csv',index_col=0)

# %%
# def pooling_data(n_scans,start_name='Dataset_'):
#     dataset_pooled=pd.concat([pd.read_csv(start_name+'{}.csv'.format(i)) for i in range(n_scans)])
#     return dataset_pooled

# full_dataset=pooling_data(7)
# full_dataset.head(2)
# full_dataset.columns
# full_dataset['Epoch'].unique()
# full_dataset.to_csv('data/Poling_dataset.csv')

# %%
# Out:
# 0
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_0.csv
# 1
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_1.csv
# 2
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_2.csv
# 3
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_3.csv
# 4
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_4.csv
# 5
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_5.csv
# 6
# C:/Users/DIONE Oumar/Desktop/DSSA/infrastructures/YouTrend/data/Dataset_6.csv
